# %% [markdown]
# Introdução Matplotlib

# %%
import matplotlib.pyplot as plt
import pandas as pd
pd.read_csv('Tomato.csv')
df_csv = pd.read_csv('Tomato.csv')

# %%
df_csv.head()
# Out:
#          Date Unit  Minimum  Maximum  Average  Market
# 0  2013-06-16   Kg       26       32     29.0  Tomato
# 1  2013-06-17   Kg       20       25     22.5  Tomato
# 2  2013-06-18   Kg       22       26     24.0  Tomato
# 3  2013-06-19   Kg       24       28     26.0  Tomato
# 4  2013-06-20   Kg       22       26     24.0  Tomato

# %%
df_csv.info() 
# A coluna de data esta como str
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2741 entries, 0 to 2740
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2741 non-null   str
#  1   Unit     2741 non-null   str
#  2   Minimum  2741 non-null   int64
#  3   Maximum  2741 non-null   int64
#  4   Average  2741 non-null   float64
#  5   Market   2741 non-null   str
# dtypes: float64(1), int64(2), str(3)
# memory usage: 128.6 KB

# %%
# ajustando a coluna de data
df_csv["Date"] = pd.to_datetime(df_csv["Date"])
df_csv.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2741 entries, 0 to 2740
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2741 non-null   datetime64[us]
#  1   Unit     2741 non-null   str
#  2   Minimum  2741 non-null   int64
#  3   Maximum  2741 non-null   int64
#  4   Average  2741 non-null   float64
#  5   Market   2741 non-null   str
# dtypes: datetime64[us](1), float64(1), int64(2), str(2)
# memory usage: 128.6 KB

# %%
def categorizar_tomate_media (media):
    if  media >=40 and media <= 70:
        return "tomate_medio"
    elif media < 40:
        return "tomate_pequeno"
    else:
        return "Tomatão"

# %%
#criando uma coluna nova com base na função anterior 
df_csv["categoria_tomate"] = df_csv["Average"].apply(categorizar_tomate_media)

# %%
df_csv.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2741 entries, 0 to 2740
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              2741 non-null   datetime64[us]
#  1   Unit              2741 non-null   str
#  2   Minimum           2741 non-null   int64
#  3   Maximum           2741 non-null   int64
#  4   Average           2741 non-null   float64
#  5   Market            2741 non-null   str
#  6   categoria_tomate  2741 non-null   str
# dtypes: datetime64[us](1), float64(1), int64(2), str(3)
# memory usage: 150.0 KB

# %%
#criando um grafico
plt.plot(df_csv["Date"], df_csv["Average"])
plt.xlabel("Data")
plt.ylabel("Média em kg de tomates")
plt.title("Média de tomates ao longo do tempo")
plt.show()

# %%
pd.read_excel('Chess.xlsx')
df_excel = pd.read_excel("Chess.xlsx", sheet_name="Chess")
df_excel.head()
# Out:
#    rated    created_at  last_move_at  turns victory_status winner  \
# 0  False  1.504210e+17  1.504210e+17     13      outoftime  white
# 1   True  1.504130e+17  1.504130e+17     16         resign  black
# 2   True  1.504130e+17  1.504130e+17     61           mate  white
# 3   True  1.504110e+17  1.504110e+17     61           mate  white
# 4   True  1.504030e+17  1.504030e+17     95           mate  white
#
#   increment_code       white_id  white_rating      black_id  black_rating  \
# 0           15+2       bourgris          1500          a-00          1191
# 1           5+10           a-00          1322     skinnerua          1261
# 2           5+10         ischia          1496          a-00          1500
# 3           20+0  daniamurashov          1439  adivanov2009          1454
# 4           30+3      nik221107          1523  adivanov2009          1469
#
#   opening_eco                            opening_name  opening_ply
# ...

# %%
plt.scatter(df_excel["black_rating"], df_excel['white_rating'])
plt.xlabel("Black")
plt.ylabel("White")
plt.title("Partidas de Peças Brancas e Peças Pretas")
plt.show()

# %%
df_csv.head()
# Out:
#         Date Unit  Minimum  Maximum  Average  Market categoria_tomate
# 0 2013-06-16   Kg       26       32     29.0  Tomato   tomate_pequeno
# 1 2013-06-17   Kg       20       25     22.5  Tomato   tomate_pequeno
# 2 2013-06-18   Kg       22       26     24.0  Tomato   tomate_pequeno
# 3 2013-06-19   Kg       24       28     26.0  Tomato   tomate_pequeno
# 4 2013-06-20   Kg       22       26     24.0  Tomato   tomate_pequeno

# %%
plt.bar(df_csv ['categoria_tomate'], df_csv['Average'])
plt.xlabel("Categoria de Tomate")
plt.ylabel("Média de tamanho de tomate")
plt.title("Avaliação de Tomate")
plt.show()

# %%
df_excel.groupby(["victory_status"])["turns"].mean().plot(
    kind="pie", 
    autopct="%1.0f%%"
)
plt.title("Média de Partidas dentro de status de vitória")
plt.show()
